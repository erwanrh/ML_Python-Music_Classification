# %% [markdown]
# <img align="left" src="https://www.flaticon.com/svg/vstatic/svg/1816/1816918.svg?token=exp=1612570837~hmac=a7c1bed2a8f0a2d93267ad247a42a6c6"  width="100">
#
# # Welcome to the music genre classifier
# To launch the classifier just run the next cell and type the *title and artist of the music you want to classify. Just as in Youtube !

# %%
# %run -i '03_Launch_Classifier.py'
# Out:
# _________Music genre classifier_________
# Search music : SIA Chandelier
#
#
# [youtube] 2vjPBrBU-TM: Downloading webpage
# [download] Destination: 2vjPBrBU-TM.webm
# [download] 100% of 3.77MiB in 00:0115MiB/s ETA 00:005
#
#  Done downloading, now converting ...
#
# [ffmpeg] Destination: 2vjPBrBU-TM.wav
# Deleting original file 2vjPBrBU-TM.webm (pass -k to keep)
# [youtube] 2vjPBrBU-TM: Downloading webpage
#
#  Download Done
#
#
#        Starting features extraction...
#
# 10% - Loading Soundwave
# 30% - Computing MFCCs
# 50% - Computing Chromas
# 70% - Computing Tempo
# 100% - Audio features extracted
#
# Audio file deleted
#
#          Starting classification...
#
# Genre for Sia - Chandelier (Official Music Video) is : blues
