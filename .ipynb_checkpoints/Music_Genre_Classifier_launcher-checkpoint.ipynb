# %% [markdown]
# # Music Genre Classifier
# ##### Ben Baccar Lilia, Rahis Erwan
# To launch the classifier just run the last cell and then type the title and artist of the music you want to classify. Just as in Youtube !

# %%
#Run this cell only ONCE to change working directory
#%cd "Python" #Run this on windows
# %cd 'Python' #Run this on mac
# Out:
# [Errno 2] No such file or directory: 'Python'
# /Users/erwanrahis/Documents/Cours/MS/S1/Machine_Learning_Python/ML_Python-Music_Classification.nosync/Python

# %%
# %run -i "03_Launch_Classifier.py"
# Out:
# Loading Keras model...
# C:\Users\lilia\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# Model loaded
# Loading scaler
# ___________________Music genre classifier___________________
# Search music : billie eilish
#
#
# [youtube] RUQl6YcMalg: Downloading webpage
# [download] Destination: RUQl6YcMalg.m4a
# [download] 100% of 4.61MiB in 00:24
#
#  Done downloading, now converting ...
#
# [ffmpeg] Destination: RUQl6YcMalg.wav
# Deleting original file RUQl6YcMalg.m4a (pass -k to keep)
# [youtube] RUQl6YcMalg: Downloading webpage
#
#  Download Done
#
#        Starting features extraction...
#
# 10% - Loading Soundwave
# 30% - Computing MFCCs
# 50% - Computing Chromas
# 70% - Computing Tempo
# 80% - Computing Zero crossing rates
# 90% - Computing Spectral Roll Off
# 100% - Audio features extracted
#
# Audio file deleted
#
#          Starting classification...
#
# Genre for Billie Eilish - Therefore I Am (Official Music Video) is : hiphop
