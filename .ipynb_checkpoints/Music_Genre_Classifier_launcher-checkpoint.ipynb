# %% [markdown]
# <img align="right" src="https://www.flaticon.com/svg/vstatic/svg/1816/1816918.svg?token=exp=1612570837~hmac=a7c1bed2a8f0a2d93267ad247a42a6c6"  width="100">
#
# # Music Genre Classifier
# ### Ben Baccar Lilia, Rahis Erwan
# To launch the classifier just run the next cell and then type the title and artist of the music you want to classify. Just as in Youtube !

# %%
# %cd 'Python'
# %run -i '03_Launch_Classifier.py'
# Out:
# [Errno 2] No such file or directory: 'Python'
# /Users/erwanrahis/Documents/Cours/MS/S1/Machine_Learning_Python/ML_Python-Music_Classification.nosync/Python
# Loading Keras model...
# Model loaded
# _________Music genre classifier_________
# Search music : rolling stones you can't always get what you want
#
#
# [youtube] krxU5Y9lCS8: Downloading webpage
# [download] Destination: krxU5Y9lCS8.webm
# [download] 100% of 7.18MiB in 00:0305MiB/s ETA 00:009
#
#  Done downloading, now converting ...
#
# [ffmpeg] Destination: krxU5Y9lCS8.wav
# Deleting original file krxU5Y9lCS8.webm (pass -k to keep)
# [youtube] krxU5Y9lCS8: Downloading webpage
#
#  Download Done
#
#        Starting features extraction...
#
# 10% - Loading Soundwave
# 30% - Computing MFCCs
# 50% - Computing Chromas
# 70% - Computing Tempo
# 100% - Audio features extracted
#
# Audio file deleted
#
#          Starting classification...
#
# ...
